# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/abalone.csv')
data.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
data.shape
# Out:
# (4177, 9)

# %%
data.tail()
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12

# %%
data.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
data.skew()
# Out:
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# Rings             1.114102
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.boxplot(data['Length'])
# Out:
# C:\Users\RitikaGugu\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Length'>

# %%
sns.boxplot(data['Diameter'])
# Out:
# C:\Users\RitikaGugu\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Diameter'>

# %%
sns.boxplot(data['Height'])
# Out:
# C:\Users\RitikaGugu\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Height'>

# %%
sns.boxplot(data['Whole weight'])
# Out:
# C:\Users\RitikaGugu\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Whole weight'>

# %%
sns.boxplot(data['Shucked weight'])
# Out:
# C:\Users\RitikaGugu\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Shucked weight'>

# %%
sns.boxplot(data['Viscera weight'])
# Out:
# C:\Users\RitikaGugu\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Viscera weight'>

# %%
sns.boxplot(data['Shell weight'])
# Out:
# C:\Users\RitikaGugu\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Shell weight'>

# %%
from scipy.stats import zscore

# %%
z_score = zscore(data[['Length','Diameter','Height','Whole weight','Shucked weight','Viscera weight','Shell weight']])
abs_z_score=np.abs(z_score)

filtering_entry = (abs_z_score < 3).all(axis=1)

data_a=data[filtering_entry]

data.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
data_a.skew()
# Out:
# Length           -0.633786
# Diameter         -0.605450
# Height           -0.247192
# Whole weight      0.323886
# Shucked weight    0.449573
# Viscera weight    0.429932
# Shell weight      0.358512
# Rings             1.136367
# dtype: float64

# %%
data.shape
# Out:
# (4177, 9)

# %%
data_a.shape
# Out:
# (4084, 9)

# %%
#Lets continue with data_a

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df2 = le.fit_transform(data_a['Sex'])
pd.Series(df2)
# Out:
# 0       2
# 1       2
# 2       0
# 3       2
# 4       1
#        ..
# 4079    0
# 4080    2
# 4081    2
# 4082    0
# 4083    2
# Length: 4084, dtype: int32

# %%
data_a['Sex'] = df2
# Out:
# <ipython-input-23-c0b479b95a6f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_a['Sex'] = df2

# %%
data_a.head()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight  Rings
# 0          0.1010         0.150     15
# 1          0.0485         0.070      7
# 2          0.1415         0.210      9
# 3          0.1140         0.155     10
# 4          0.0395         0.055      7

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1

for column in data_a:
    if plotnumber<=9:   # as there are 9 columns in the data
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(data_a[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
plt.show()
# Out:
# C:\Users\RitikaGugu\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\RitikaGugu\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
#Now our data may be its normal distributed

# %%
# it is a Linear regression data having Rings is a target variable.

# %%
x=data_a.drop(columns=['Rings'])
y=data_a['Rings']

# %%
# Lets see how features are related to class
plt.figure(figsize=(15,30),facecolor='white')
plotnumber = 1

for column in x:
    if plotnumber<=9:
        ax = plt.subplot(3,3,plotnumber)
        sns.scatterplot(y,x[column])
    plotnumber+=1
plt.tight_layout()
# Out:
# C:\Users\RitikaGugu\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\RitikaGugu\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\RitikaGugu\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %%
x
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight
# 0             0.1010        0.1500
# 1             0.0485        0.0700
# 2             0.1415        0.2100
# ...

# %%
y
# Out:
# 0       15
# 1        7
# 2        9
# 3       10
# 4        7
#         ..
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4084, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import statsmodels.api as sm

# %%
scaler = StandardScaler()

x_scaled = scaler.fit_transform(x)

# %%
x_scaled
# Out:
# array([[ 1.1577438 , -0.5798883 , -0.43102345, ..., -0.61064456,
#         -0.73148499, -0.64218694],
#        [ 1.1577438 , -1.48745122, -1.47447322, ..., -1.21802438,
#         -1.23959876, -1.26010684],
#        [-1.28011425,  0.06837092,  0.14287393, ..., -0.45515533,
#         -0.33951152, -0.17874702],
#        ...,
#        [ 1.1577438 ,  0.67341287,  0.7167713 , ...,  0.85192604,
#          1.07352867,  0.57820485],
#        [-1.28011425,  0.88949928,  0.82111628, ...,  0.87865076,
#          0.81705219,  0.48551686],
#        [ 1.1577438 ,  1.62419307,  1.55153111, ...,  2.89272223,
#          1.93490248,  2.0225926 ]])

# %%
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size=0.25,random_state=21)
y_train.head()
# Out:
# 128     19
# 674     23
# 3397    12
# 307     13
# 2541     9
# Name: Rings, dtype: int64

# %% [markdown]
# # Model instantiating and training

# %%
regression = LinearRegression()
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
data_a.tail(2)
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 4175          0.2610         0.296     10
# 4176          0.3765         0.495     12

# %%
print('Rings  : ',regression.predict(scaler.transform([[0,0.625,0.485,0.150,1.0945,0.5310,0.2610,0.296]])))
# Out:
# Rings  :  [9.21897549]

# %%
print('Rings  : ',regression.predict(scaler.transform([[2,0.710,0.555,0.195,1.9485,0.9455,0.3765,0.495]])))
# Out:
# Rings  :  [10.88166955]

# %%
# our model output is almost same.

# %%
regression.score(x_train,y_train)
# Out:
# 0.5295448528044464

# %%
regression.score(x_test,y_test)
# Out:
# 0.5110178400458798

# %%
pred_test = regression.predict(x_test)

# %%
from sklearn.metrics import r2_score

print(r2_score(y_test,pred_test))
# Out:
# 0.5110178400458798

# %% [markdown]
# Regularization

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')
from sklearn.linear_model import Lasso

# %%
parameters = {'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}
ls = Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.001, 'random_state': 0}

# %%
ls= Lasso(alpha=0.001,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls = ls.predict(x_test)

lss = r2_score(y_test,pred_ls)

lss
# Out:
# 0.5108215359434223

# %%
cv_score=cross_val_score(ls,x,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.3932426350398394

# %% [markdown]
# # Ensemble Technique

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters = {'criterion':['mse','mae'],'max_features':["auto","sqrt","log2"]}
rf = RandomForestRegressor()
clf = GridSearchCV(rf,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'log2'}

# %%
rf=RandomForestRegressor(criterion='mse',max_features='log2')
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
pred_decision = rf.predict(x_test)

rfs = r2_score(y_test,pred_decision)
print('R2 score:',rfs*100)

rfscore = cross_val_score(rf,x,y,cv=5)
rfc = rfscore.mean()
print('Cross Val Score:',rfc*100)
# Out:
# R2 score: 52.548796657007514
# Cross Val Score: 43.59407464562565

# %%
#I have tried to complete but do not get the accuracy more then 50%

# %%
import pickle
filename = 'project 2b'
pickle.dump(rf,open(filename,'wb' ))
